# %% [markdown]
# ### Reading Data from CSV File

# %%
import pandas as pd

df = pd.read_csv('StockPriceData.csv' , usecols = ['Adj Close'])

# %% [markdown]
# ### Plot

# %%
df.plot()

# %%
df.rolling(100).mean().plot()

# %%
MySmoothe= df.rolling(100).mean()

# %%
df["mynewcolumn"] = MySmoothe

# %%
df.head(20)
# Out:
#     Adj Close  mynewcolumn
# 0    1.718597          NaN
# 1    1.730313          NaN
# 2    1.728101          NaN
# 3    1.720697          NaN
# 4    1.733102          NaN
# 5    1.734214          NaN
# 6    1.745414          NaN
# 7    1.739796          NaN
# 8    1.746206          NaN
# 9    1.747305          NaN
# 10   1.747305          NaN
# 11   1.754201          NaN
# 12   1.765506          NaN
# 13   1.771009          NaN
# 14   1.765194          NaN
# 15   1.764291          NaN
# 16   1.764197          NaN
# 17   1.775600          NaN
# 18   1.775411          NaN
# 19   1.772013          NaN

# %%
df.dropna()
# Out:
#       Adj Close  mynewcolumn
# 99     1.796300     1.817224
# 100    1.807109     1.818109
# 101    1.785300     1.818659
# 102    1.769504     1.819073
# 103    1.775285     1.819619
# 104    1.773207     1.820020
# 105    1.786001     1.820538
# 106    1.791890     1.821002
# 107    1.771009     1.821315
# 108    1.773396     1.821586
# 109    1.778600     1.821899
# 110    1.771385     1.822140
# 111    1.795687     1.822555
# 112    1.790991     1.822810
# 113    1.794591     1.823046
# 114    1.789197     1.823286
# 115    1.777209     1.823415
# 116    1.760315     1.823376
# 117    1.772201     1.823342
# 118    1.760315     1.823191
# 119    1.758613     1.823057
# 120    1.771197     1.823024
# 121    1.766785     1.822912
# 122    1.782086     1.822845
# 123    1.775505     1.822748
# 124    1.789613     1.822707
# 125    1.791697     1.822552
# 126    1.812513     1.822464
# 127    1.814915     1.822435
# 128    1.836615     1.822463
# ...         ...          ...
# ...

# %%
df.plot()
