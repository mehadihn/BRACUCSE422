# %% [markdown]
# ### Reading Data from CSV File

# %%
import pandas as pd

df = pd.read_csv('StockPriceData.csv')

# %% [markdown]
# ### Plot

# %%
df.plot()

# %%
df.rolling(100, win_type ='triang').mean().plot()

# %%
MySmoothe= df.rolling(100 , win_type ='triang').mean()

# %%
df['mynewcolumn'] = MySmoothe
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'mynewcolumn'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.head(20)
# Out:
#           Date      Open      High       Low     Close  Adj Close  Volume
# 0    12/1/2003  1.723811  1.727205  1.718390  1.718597   1.718597     0.0
# 1    12/2/2003  1.719010  1.732112  1.717298  1.730313   1.730313     0.0
# 2    12/3/2003  1.730493  1.731812  1.725209  1.728101   1.728101     0.0
# 3    12/4/2003  1.727414  1.728997  1.718302  1.720697   1.720697     0.0
# 4    12/5/2003  1.720608  1.733102  1.719809  1.733102   1.733102     0.0
# 5    12/8/2003  1.733102  1.736202  1.727504  1.734214   1.734214     0.0
# 6    12/9/2003  1.733703  1.747793  1.733613  1.745414   1.745414     0.0
# 7   12/10/2003  1.745292  1.748007  1.735900  1.739796   1.739796     0.0
# 8   12/11/2003  1.740008  1.747702  1.737891  1.746206   1.746206     0.0
# 9   12/12/2003  1.746298  1.751099  1.744287  1.747305   1.747305     0.0
# 10  12/15/2003  1.747305  1.748588  1.738889  1.747305   1.747305     0.0
# 11  12/16/2003  1.747213  1.756111  1.744014  1.754201   1.754201     0.0
# ...

# %%
df.plot()
